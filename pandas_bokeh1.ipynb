# %%
import pandas as pd
import pandas_bokeh
from bokeh.io import output_file, save
pandas_bokeh.output_notebook()

df = pd.DataFrame({'x':[1,2,3,4,5], 'y':[3,4,2,1,3]})
p = df.plot_bokeh()

output_file('lines.html')
save(p)
# Out:
#   <div class="bk-root" id="95d213ee-3cfd-46d8-8196-a501792741bf" data-root-id="1002"></div>
# '/content/lines.html'
